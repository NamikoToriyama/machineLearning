# %%
from sklearn.datasets import samples_generator
from sklearn.manifold import LocallyLinearEmbedding
import matplotlib.pyplot as plt
from matplotlib.image import imread
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA

# %%
data, color = samples_generator.make_swiss_roll(n_samples=1500)

# 元の3Dグラフの表示
data_3d =  list(zip(*data))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(data_3d[0], data_3d[1], data_3d[2], c=color)
plt.show()

n_neighbors = 12 # 近傍点の数
n_components = 2 # 削減後の次元数
model = LocallyLinearEmbedding(n_neighbors=n_neighbors,n_components=n_components)

model.fit(data)
print(model.transform(data))
transform_data = model.transform(data)
# Out:
# [[-0.02812941 -0.02026862]
#  [-0.03235554  0.02734831]
#  [ 0.04940537 -0.01275229]
#  ...
#  [ 0.02900525 -0.00139319]
#  [ 0.00101635  0.03341413]
#  [ 0.04775503 -0.01620392]]

# %%
data2 = list(zip(*transform_data))

plt.scatter(data2[0], data2[1], c=color)

# %% [markdown]
# # PCAで描画する

# %%
n_components = 2 # 次元削減後の次元を２にする
model2 = PCA(n_components=n_components)
model2 = model2.fit(data.data)
transform_data = model2.transform(data.data) # 変換したデータ
data2 = list(zip(*transform_data))

plt.scatter(data2[0], data2[1], c=color)

# %% [markdown]
# # 近傍点の違いをみる(本と若干違った)

# %%
n_neighbors = 5 # 近傍点の数
n_components = 2 # 削減後の次元数
model = LocallyLinearEmbedding(n_neighbors=n_neighbors,n_components=n_components)

model.fit(data)
transform_data = model.transform(data)
data2 = list(zip(*transform_data))

plt.scatter(data2[0], data2[1], c=color)

# %%
n_neighbors = 50 # 近傍点の数
n_components = 2 # 削減後の次元数
model = LocallyLinearEmbedding(n_neighbors=n_neighbors,n_components=n_components)

model.fit(data)
transform_data = model.transform(data)
data2 = list(zip(*transform_data))

plt.scatter(data2[0], data2[1], c=color)
